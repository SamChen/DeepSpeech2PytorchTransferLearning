# %%
import sys
sys.path.append("..")

# %%
import model_utils.network as network

# %%
test = network.deepspeech_hiddenlayers(device='cpu')

# %%
test.load_pretrained()
# Out:
# OrderedDict([('conv_bn_mask0.conv.weight',
#               tensor([[[[ 9.2931e-02, -1.0305e-01,  2.6686e-03,  ..., -2.8961e-02,
#                           7.0959e-02,  6.8781e-02],
#                         [-4.2692e-01, -2.5483e-02,  2.2691e-01,  ..., -2.9990e-01,
#                           1.1172e-01,  1.0989e-01],
#                         [ 2.6215e-01,  4.3179e-01,  2.8421e-01,  ...,  1.7255e-01,
#                           1.0563e-01,  8.3155e-02],
#                         ...,
#                         [ 2.8560e-01,  2.8845e-01,  2.9285e-01,  ..., -6.1134e-02,
#                          -9.5798e-02,  3.0908e-01],
#                         [ 2.8250e-01,  2.0411e-01,  1.8365e-02,  ..., -2.2836e-01,
#                          -7.5250e-02, -1.9264e-02],
#                         [-6.2943e-03,  1.6898e-01,  2.2596e-01,  ..., -1.8092e-02,
#                          -4.6523e-02, -5.3179e-02]]],
#
#
# ...
